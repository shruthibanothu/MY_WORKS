# %% [markdown]
# 📌 Problem Statement
#
# You are given a flight booking dataset from an online ticket booking platform.
# Your task is to analyze the data, perform EDA, visualize key patterns, and build ML models to predict flight prices.
#
#
# 🧪 Tasks to Perform
#
# 1️⃣ Data Understanding & Cleaning
#
# Load the dataset and check shape, data types, and basic statistics
#
# Check for null values and duplicate records
#
# Remove unnecessary columns (if any)
#
#
# 2️⃣ Exploratory Data Analysis (EDA)
#
# Analyze how price varies with different airlines
#
# Study the relationship between price and days left for departure
#
# Visualize overall price distribution
#
# Compare Economy vs Business class prices
#
# Analyze price variation based on source and destination cities
#
# Visualize all categorical features using count plots
#
#
# 3️⃣ Feature Engineering
#
# Encode categorical variables
#
# Perform correlation analysis
#
# Use VIF to detect multicollinearity and drop high-VIF features
#
#
# 4️⃣ Model Building
#
# Apply Linear Regression and evaluate using RMSE, MAE
#
# Build a Decision Tree Regressor and evaluate
#
# Build a Random Forest Regressor and evaluate
#
#
# 5️⃣ Model Comparison
#
# Compare all models using evaluation metrics
#
# Identify the best performing model and justify your choice
