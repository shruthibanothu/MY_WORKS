# %% [markdown]
# <a href="https://colab.research.google.com/github/shruthibanothu/MY_WORKS/blob/main/Weeked_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# https://colab.research.google.com/drive/1l2FIoRJmaF9vly-fszafogr9NKTNtMZD?usp=sharing

# %%
url="https://raw.githubusercontent.com/IBM/telco-customer-churn-on-icp4d/master/data/Telco-Customer-Churn.csv"
data = pd.read_csv(url)
data

# %%
pd.set_option('display.max_columns', None)
data.head()

# %%
data.shape

# %%
data.info()

# %%
data.describe()

# %%
data['Churn']= data['Churn'].map({"No":0, "Yes":1})

# %%
data['Churn'].value_counts()

# %%
data['gender'].value_counts()

# %%
data['gender']=data['gender'].map({"Female":0,"Male":1})

# %%
data['TotalCharges']=pd.to_numeric(data['TotalCharges'],errors="coerce")

# %%
data.drop(columns=['customerID'],inplace=True, errors='ignore')
data.head(2)

# %%
data.isnull().sum()

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()

# %%
# testing vs production
# testing->uses in local works
#production-> uses in actula problem
#feature elimination->recursive feature elimination
data.columns

# %%
numerical_feature=['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
       'MonthlyCharges', 'TotalCharges']


#lets take each features line by line and convert thee columns to numbers
for col in numerical_feature:
  if data[col].dtype == "object":
    data[col]=pd.factorize(data[col])[0]

#double check
numerical_feature = [f for f in numerical_feature if f in data.columns]
numerical_feature

# %%
# arr ={'shyny','pinky', 'shanky','sham'}
# for i in arr:
#   print(i)

# val=[i for i in arr]
# val
# list compherneces
# https://www.w3schools.com/python/python_lists_comprehension.asp

# %%
x= data[numerical_feature]
y= data['Churn']

# %%
#  for working with recursive selection
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

# %%
# recursive feature selection
x_train, x_test, y_train,y_test = train_test_split(
    x,y,test_size=0.20,stratify=y) # stratify means balancing the data
    # giving the data example training and testing split in equally

# %%
print(f"traing data : {x_train.shape[0]}")
print(f"testing data : {x_test.shape[0]}")

# %%
# RFE -> WE NEED A BSE ALGORITHM
rf = RandomForestClassifier(n_estimators=150)
