# %% [markdown]
# <a href="https://colab.research.google.com/github/shruthibanothu/learning-sql/blob/main/fashoin_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  referece: https://colab.research.google.com/drive/1cmHWeOoQyUuTzgj6DbJMI5Tt2b88BWn8?usp=sharing

# %%
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt

# %%
(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()

# %%
print(x_train[0])

# %%
#visualize in image format
plt.imshow(x_train[0],cmap='grey')
plt.title(f"label: {y_train[0]}")
plt.show()

# %%
x_train = x_train/255
x_test= x_test/255

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten

# %%
model = Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128, activation='relu'),  #relu max(0,infinite)
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
    ])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
#training
history = model.fit(x_train,y_train, epochs=10, batch_size=10,
                    validation_data=(x_test,y_test), verbose=1)

# %%
plt.plot(history.history['accuracy'],label='train_acc')
plt.plot(history.history['val_accuracy'],label='val_acc')
plt.legend()
plt.show()

# %%
loss, acc=model.evaluate(x_test,y_test)
print(f"loss={loss}, accuracy={acc}")

# %%
import numpy as np
a = np.array([1,2,3])
print(np.argmax(a))  # a

pred = model.predict(x_test)

idx = 4

plt.imshow(x_test[idx].reshape(28,28),cmap='gray')
plt.title(f"Actual:{y_test[idx]} | prediction: {np.argmax(pred[idx])}")
plt.show()
